# %%
# !pip install --upgrade pip
# !pip install imutils
# !pip install opencv-python
# !pip install --upgrade scikit-learn==0.23.0
# Out:
# Requirement already satisfied: pip in /srv/conda/envs/notebook/lib/python3.7/site-packages (21.1.2)
# Requirement already satisfied: imutils in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.5.4)
# Requirement already satisfied: opencv-python in /srv/conda/envs/notebook/lib/python3.7/site-packages (4.5.2.52)
# Requirement already satisfied: numpy>=1.14.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from opencv-python) (1.20.2)
# Requirement already satisfied: scikit-learn==0.23.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.23.0)
# Requirement already satisfied: numpy>=1.13.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn==0.23.0) (1.20.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn==0.23.0) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn==0.23.0) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn==0.23.0) (1.0.1)

# %%
from IPython.display import Image
from imutils import paths
import numpy as np
import cv2
import os

# %%
def extract_histogram(image, bins=(8, 8, 8)):
    hist = cv2.calcHist([image], [0, 1, 2], None, bins, [0, 256, 0, 256, 0, 256])
    cv2.normalize(hist, hist)
    return hist.flatten()

# %%
imagePaths = sorted(list(paths.list_images('train')))
trainData = []
labels = []

for (i, imagePath) in enumerate(imagePaths):
    image = cv2.imread(imagePath, 1)
    label = imagePath.split(os.path.sep)[-1].split(".")[0]
    hist = extract_histogram(image)
    trainData.append(hist)
    labels.append(label)

# %%
Y = [1 if x == 'cat' else 0 for x in labels]

# %%
print(Y[0])
Image(filename=imagePaths[0])
# Out:
# 1

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion='entropy', #критерий разделения
                              min_samples_leaf=10, #минимальное число объектов в листе
                              max_leaf_nodes=20, #максимальное число листьев
                              random_state=288)
bagging = BaggingClassifier(tree, #базовый алгоритм
                            n_estimators=21, #количество деревьев
                            random_state=288)
bagging.fit(trainData, Y)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                         max_leaf_nodes=20,
#                                                         min_samples_leaf=10,
#                                                         random_state=288),
#                   n_estimators=21, random_state=288)

# %%
from sklearn.svm import LinearSVC

svm = LinearSVC(random_state = 288, C = 1.19)
svm.fit(trainData, Y)
# Out:
# LinearSVC(C=1.19, random_state=288)

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=21, #количество деревьев
                             criterion='entropy', #критерий разделения
                              min_samples_leaf=10, #минимальное число объектов в листе
                              max_leaf_nodes=20, #максимальное число листьев
                              random_state=288)
forest.fit(trainData, Y)
# Out:
# RandomForestClassifier(criterion='entropy', max_leaf_nodes=20,
#                        min_samples_leaf=10, n_estimators=21, random_state=288)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(solver='lbfgs', random_state=288)

# %%
from sklearn.ensemble import StackingClassifier

base_estimators = [('SVM', svm), ('Bagging DT', bagging), ('DecisionForest', forest)]
sclf = StackingClassifier(estimators=base_estimators, final_estimator=lr, cv=2)
sclf.fit(trainData, Y)
# Out:
# StackingClassifier(cv=2,
#                    estimators=[('SVM', LinearSVC(C=1.19, random_state=288)),
#                                ('Bagging DT',
#                                 BaggingClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                                                         max_leaf_nodes=20,
#                                                                                         min_samples_leaf=10,
#                                                                                         random_state=288),
#                                                   n_estimators=21,
#                                                   random_state=288)),
#                                ('DecisionForest',
#                                 RandomForestClassifier(criterion='entropy',
#                                                        max_leaf_nodes=20,
#                                                        min_samples_leaf=10,
#                                                        n_estimators=21,
#                                                        random_state=288))],
#                    final_estimator=LogisticRegression(random_state=288))

# %%
sclf.score(trainData, Y)
# Out:
# 0.851

# %%
singleImage = cv2.imread('test/dog.1041.jpg')
histt = extract_histogram(singleImage)
histt2 = histt.reshape(1, -1)
prediction = sclf.predict(histt2)

# %%
Image(filename='test/dog.1041.jpg')

# %%
prediction
# Out:
# array([0])

# %%
sclf.predict_proba(histt2)
# Out:
# array([[0.66398879, 0.33601121]])

# %%
singleImage = cv2.imread('test/dog.1025.jpg')
histt = extract_histogram(singleImage)
histt2 = histt.reshape(1, -1)
prediction = sclf.predict(histt2)

# %%
Image(filename='test/dog.1025.jpg')

# %%
prediction
# Out:
# array([1])

# %%
sclf.predict_proba(histt2)
# Out:
# array([[0.42742237, 0.57257763]])
