# %%
import numpy as np

# %%
scores = np.genfromtxt('X_reduced_791.csv', delimiter=';')
loadings = np.genfromtxt('X_loadings_791.csv', delimiter=';')

# %%
values = np.dot(scores,loadings.T)

# %%
#Импорт библиотеки
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
#Создание изображения
plt.imshow(values, cmap='Greys_r')
